# %%
import pandas as pd

# %%
baseline = [0.5, 0.38, 0.29, 0.22, 0.06, 0.06, 0.03, 0.02]
production = [0.4, 0.48, 0.2, 0.2, 0.03, 0.04, 0.02, 0.02]
index = ['MedInc', 'Latitude', 'Longitude', 'AveOccup', 'HouseAge', 'AveRooms','AveBedrms', 'Population']
df = pd.DataFrame({'basline': baseline,
                    'production': production}, index=index)
ax = df.plot.barh()
